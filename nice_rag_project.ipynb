# %% [markdown]
# <a href="https://colab.research.google.com/github/bihterk/006_ConfigXMLSpEL/blob/master/nice_rag_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/LAB-FAM/nice-rag-project.git
# Out:
# Cloning into 'nice-rag-project'...
# fatal: could not read Username for 'https://github.com': No such device or address
